# %%
from Basil import Finder, tools

# %%
finder = Finder(subject=("fox", "tiger"), out_dir="/home/cna/Desktop/", automate=True)
# Out:
# Train
# 1523 images
# find objects100% (1910098 of 1910098) |##| Elapsed Time: 0:01:38 Time:  0:01:38
# 1825 objects
# train_01 100% (133 of 133) |#############| Elapsed Time: 0:01:00 Time:  0:01:00
# train_02 100% (136 of 136) |#############| Elapsed Time: 0:01:01 Time:  0:01:01
# train_00 100% (139 of 139) |#############| Elapsed Time: 0:01:02 Time:  0:01:02
# train_03 100% (139 of 139) |#############| Elapsed Time: 0:01:03 Time:  0:01:03
# train_05 100% (150 of 150) |#############| Elapsed Time: 0:01:09 Time:  0:01:09
# train_06 100% (150 of 150) |#############| Elapsed Time: 0:01:08 Time:  0:01:08
# train_04 100% (161 of 161) |#############| Elapsed Time: 0:01:11 Time:  0:01:11
# train_07 100% (281 of 281) |#############| Elapsed Time: 0:01:29 Time:  0:01:29
# train_08 100% (234 of 234) |#############| Elapsed Time: 0:00:26 Time:  0:00:26
# TFRecords created in records: /home/cna/Desktop/data/records/Train.record
# Validation
# 52 images
# ...

# %% [markdown]
# #### Find and Save them

# %%
finder.extract_images(dirs=("Validation", ))

# %% [markdown]
# #### Test bboxes

# %%
finder.bbox_test(target="Validation", n=4, thickness=10)

# %%
tools.mid_to_string("Apple")
# Out:
# '/m/014j1m'
