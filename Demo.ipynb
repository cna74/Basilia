# %%
from Basil import Finder

# %%
Finder(subject="apple", input_dir="/media/cna/backpack/dataset/Open-Image/",
       out_dir="/home/cna/Desktop/", resource="jpg", automate=True)
# Out:
# /home/cna/Desktop/data is already exist,
# (y) remove files and folders in it
# (Enter) i was working on this dir now i want to resume
# (y/n)?y
# searching for ['Apple']
# Train
# 1078 images
# find objects100% (1910098 of 1910098) |##| Elapsed Time: 0:01:07 Time:  0:01:07
# 3860 objects
# train_03  94% (103 of 109) |############ | Elapsed Time: 0:00:41 ETA:   0:00:02
# train_01 100% (101 of 101) |#############| Elapsed Time: 0:00:41 Time:  0:00:41
# train_03 100% (109 of 109) |#############| Elapsed Time: 0:00:43 Time:  0:00:43
# train_02 100% (109 of 109) |#############| Elapsed Time: 0:00:44 Time:  0:00:44
# train_04 100% (116 of 116) |#############| Elapsed Time: 0:00:47 Time:  0:00:47
# train_06 100% (113 of 113) |#############| Elapsed Time: 0:00:45 Time:  0:00:45
# train_05 100% (136 of 136) |#############| Elapsed Time: 0:00:52 Time:  0:00:52
# train_07 100% (144 of 144) |#############| Elapsed Time: 0:00:51 Time:  0:00:51
# ...

# %%
Finder(subject="Fruit", is_group=True, out_dir="/home/cna/Desktop/", automate=True)

# %%
Finder(subject="Doll", is_depiction=True, out_dir="/home/cna/Desktop/", automate=True)

# %%
Finder(subject="Airplane", is_inside=True, out_dir="/home/cna/Desktop/", automate=True)

# %%
Finder(subject="Taxi", is_occluded=True, out_dir="/home/cna/Desktop/", automate=True)

# %%
Finder(subject="Goldfish", is_truncated=True, out_dir="/home/cna/Desktop/", automate=True)

# %%
Finder(subject=("fox", "tiger", "jaguar"), is_group=False, out_dir="/home/cna/Desktop/", automate=True)

# %%
finder = Finder(is_depiction=True, is_truncated=False, is_group=False, is_occluded=False,
                is_inside=False, just_count_images=True, automate=True, out_dir="/home/cna/Desktop/")
